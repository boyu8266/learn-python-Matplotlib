# %% [markdown]
# # Import

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Data

# %%
x = np.linspace(-3, 3, 50)
y = (2 * x) + 1

# %% [markdown]
# # Draw

# %%
plt.figure(num=1, figsize=(8,5))
plt.plot(x, y)

# 移動座標
ax = plt.gca()
ax.spines['right']
ax.spines['top']
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data', 0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data', 0))

# 點
xp = 1
yp = (2 * xp) + 1
plt.scatter(xp, yp, s=50, color='orange')

# 虛線
plt.plot([xp, xp], [yp, 0], 'k--', lw=2.5)

# 註解1
plt.annotate(r'$2x + 1 = %s$' % yp, xy=(xp, yp), xycoords='data', xytext=(+30, -30), textcoords='offset points',
            fontsize=16, arrowprops=dict(arrowstyle='->', connectionstyle='arc3, rad=.2'))

# 註解2
plt.text(-3.7, 3, r'$This\ is\ the\ some\ text.$')
# Out:
# Text(-3.7, 3, '$This\\ is\\ the\\ some\\ text.$')
